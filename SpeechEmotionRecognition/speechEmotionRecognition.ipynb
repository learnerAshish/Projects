# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the Dataset

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('dataset'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['dataset\\OAF_angry\\OAF_back_angry.wav',
#  'dataset\\OAF_angry\\OAF_bar_angry.wav',
#  'dataset\\OAF_angry\\OAF_base_angry.wav',
#  'dataset\\OAF_angry\\OAF_bath_angry.wav',
#  'dataset\\OAF_angry\\OAF_bean_angry.wav']

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                  speech  label
# 0  dataset\OAF_angry\OAF_back_angry.wav  angry
# 1   dataset\OAF_angry\OAF_bar_angry.wav  angry
# 2  dataset\OAF_angry\OAF_base_angry.wav  angry
# 3  dataset\OAF_angry\OAF_bath_angry.wav  angry
# 4  dataset\OAF_angry\OAF_bean_angry.wav  angry

# %%
df['label'].value_counts()
# Out:
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: label, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df['label'] = df['label'].astype('category')
sns.countplot(data=df, x='label')
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
def waveshow(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveshow(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Feature Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.96986206e+02,  7.74405365e+01, -1.95927906e+01, -2.16666889e+01,
#        -2.11275506e+00,  1.00753632e+01, -2.03667068e+01, -6.09244919e+00,
#        -7.21228313e+00, -5.57365894e-01, -1.83255327e+00,  2.02101514e-01,
#         7.27551103e-01,  1.31773770e+00,  2.88633752e+00,  2.85579133e+00,
#        -4.71292162e+00, -4.43651056e+00, -1.62115920e+00, -1.02398405e+01,
#        -7.55126143e+00, -1.79688025e+00, -7.03765202e+00,  9.43658447e+00,
#         8.35585499e+00,  2.17123604e+01,  1.92169895e+01,  2.03489265e+01,
#         1.34133663e+01,  8.33917141e+00,  3.94722402e-01,  5.11131477e+00,
#         9.56873894e+00,  5.45486784e+00,  2.50996375e+00, -1.82390726e+00,
#         4.86896276e+00,  9.31392288e+00,  2.08915043e+00, -1.90649128e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.65600896, -32.74544, ...
# 2       [-429.79196, 46.124, 1.5550478, -0.21709506, 2...
# 3       [-403.46118, 76.32369, -12.531774, -22.288858,...
# 4       [-434.05756, 77.4455, 10.8655, 16.092943, 8.04...
#                               ...
# 2795    [-553.2201, 89.83577, 27.215466, 16.407124, 19...
# 2796    [-589.23676, 96.20408, 36.96118, 15.014448, 28...
# 2797    [-533.41815, 85.43242, 27.791998, 19.307178, 2...
# 2798    [-548.6142, 110.16424, 31.910236, 12.572517, 2...
# 2799    [-549.2962, 102.374565, 32.268833, 26.261616, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %% [markdown]
# ## Create the LSTM Model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 256)               264192
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 305,799
# Trainable params: 305,799
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 7s 131ms/step - loss: 1.1298 - accuracy: 0.5964 - val_loss: 1.2650 - val_accuracy: 0.3911
# Epoch 2/50
# 35/35 [==============================] - 4s 108ms/step - loss: 0.3876 - accuracy: 0.8719 - val_loss: 0.4221 - val_accuracy: 0.8768
# Epoch 3/50
# 35/35 [==============================] - 4s 119ms/step - loss: 0.2102 - accuracy: 0.9384 - val_loss: 0.1440 - val_accuracy: 0.9536
# Epoch 4/50
# 35/35 [==============================] - 3s 97ms/step - loss: 0.1348 - accuracy: 0.9563 - val_loss: 0.0898 - val_accuracy: 0.9661
# Epoch 5/50
# 35/35 [==============================] - 3s 93ms/step - loss: 0.1442 - accuracy: 0.9576 - val_loss: 0.4998 - val_accuracy: 0.8411
# Epoch 6/50
# 35/35 [==============================] - 3s 93ms/step - loss: 0.1221 - accuracy: 0.9643 - val_loss: 0.0862 - val_accuracy: 0.9661
# Epoch 7/50
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0678 - accuracy: 0.9817 - val_loss: 0.1330 - val_accuracy: 0.9696
# Epoch 8/50
# 35/35 [==============================] - 3s 86ms/step - loss: 0.0830 - accuracy: 0.9746 - val_loss: 0.0431 - val_accuracy: 0.9821
# Epoch 9/50
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0669 - accuracy: 0.9777 - val_loss: 0.0271 - val_accuracy: 0.9929
# Epoch 10/50
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0540 - accuracy: 0.9830 - val_loss: 0.1680 - val_accuracy: 0.9500
# Epoch 11/50
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0541 - accuracy: 0.9817 - val_loss: 0.0429 - val_accuracy: 0.9821
# Epoch 12/50
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0301 - accuracy: 0.9906 - val_loss: 0.0887 - val_accuracy: 0.9643
# Epoch 13/50
# 35/35 [==============================] - 3s 90ms/step - loss: 0.0424 - accuracy: 0.9848 - val_loss: 0.0213 - val_accuracy: 0.9946
# Epoch 14/50
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0292 - accuracy: 0.9906 - val_loss: 0.0096 - val_accuracy: 0.9982
# Epoch 15/50
# 35/35 [==============================] - 3s 92ms/step - loss: 0.0139 - accuracy: 0.9946 - val_loss: 0.0345 - val_accuracy: 0.9857
# Epoch 16/50
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0308 - accuracy: 0.9920 - val_loss: 0.0273 - val_accuracy: 0.9893
# Epoch 17/50
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0468 - accuracy: 0.9866 - val_loss: 0.0291 - val_accuracy: 0.9893
# Epoch 18/50
# 35/35 [==============================] - 3s 93ms/step - loss: 0.0267 - accuracy: 0.9920 - val_loss: 0.0256 - val_accuracy: 0.9911
# Epoch 19/50
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0456 - accuracy: 0.9844 - val_loss: 0.1484 - val_accuracy: 0.9571
# Epoch 20/50
# 35/35 [==============================] - 3s 92ms/step - loss: 0.0377 - accuracy: 0.9888 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 21/50
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0796 - accuracy: 0.9786 - val_loss: 0.0433 - val_accuracy: 0.9839
# Epoch 22/50
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0425 - accuracy: 0.9893 - val_loss: 0.0058 - val_accuracy: 1.0000
# Epoch 23/50
# 35/35 [==============================] - 3s 89ms/step - loss: 0.0107 - accuracy: 0.9982 - val_loss: 0.0223 - val_accuracy: 0.9893
# Epoch 24/50
# 35/35 [==============================] - 3s 92ms/step - loss: 0.0196 - accuracy: 0.9964 - val_loss: 0.0103 - val_accuracy: 0.9946
# Epoch 25/50
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0074 - accuracy: 0.9987 - val_loss: 0.0129 - val_accuracy: 0.9964
# Epoch 26/50
# 35/35 [==============================] - 3s 92ms/step - loss: 0.0316 - accuracy: 0.9933 - val_loss: 0.0281 - val_accuracy: 0.9911
# Epoch 27/50
# 35/35 [==============================] - 3s 90ms/step - loss: 0.0238 - accuracy: 0.9924 - val_loss: 0.0176 - val_accuracy: 0.9929
# Epoch 28/50
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0187 - accuracy: 0.9929 - val_loss: 0.0084 - val_accuracy: 0.9982
# Epoch 29/50
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0098 - accuracy: 0.9969 - val_loss: 0.0156 - val_accuracy: 0.9929
# Epoch 30/50
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0027 - val_accuracy: 0.9982
# Epoch 31/50
# 35/35 [==============================] - 3s 91ms/step - loss: 0.0400 - accuracy: 0.9893 - val_loss: 0.0954 - val_accuracy: 0.9661
# Epoch 32/50
# 35/35 [==============================] - 3s 95ms/step - loss: 0.0367 - accuracy: 0.9879 - val_loss: 0.0225 - val_accuracy: 0.9911
# Epoch 33/50
# 35/35 [==============================] - 3s 87ms/step - loss: 0.0453 - accuracy: 0.9839 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 34/50
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0167 - accuracy: 0.9942 - val_loss: 0.0069 - val_accuracy: 0.9964
# Epoch 35/50
# 35/35 [==============================] - 3s 92ms/step - loss: 0.0840 - accuracy: 0.9772 - val_loss: 0.1532 - val_accuracy: 0.9446
# Epoch 36/50
# 35/35 [==============================] - 3s 88ms/step - loss: 0.0312 - accuracy: 0.9906 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 37/50
# 35/35 [==============================] - 4s 109ms/step - loss: 0.0090 - accuracy: 0.9982 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 38/50
# 35/35 [==============================] - 3s 96ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 2.4365e-04 - val_accuracy: 1.0000
# Epoch 39/50
# 35/35 [==============================] - 3s 90ms/step - loss: 0.0047 - accuracy: 0.9982 - val_loss: 2.3940e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 35/35 [==============================] - 4s 106ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.0028 - val_accuracy: 0.9982
# Epoch 41/50
# 35/35 [==============================] - 4s 106ms/step - loss: 0.0111 - accuracy: 0.9978 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 42/50
# 35/35 [==============================] - 3s 94ms/step - loss: 0.0127 - accuracy: 0.9951 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 43/50
# 35/35 [==============================] - 3s 98ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.0043 - val_accuracy: 0.9982
# Epoch 44/50
# 35/35 [==============================] - 4s 110ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 45/50
# 35/35 [==============================] - 4s 112ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 46/50
# 35/35 [==============================] - 4s 113ms/step - loss: 0.0195 - accuracy: 0.9933 - val_loss: 0.0152 - val_accuracy: 0.9982
# Epoch 47/50
# 35/35 [==============================] - 4s 113ms/step - loss: 0.0201 - accuracy: 0.9946 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 48/50
# 35/35 [==============================] - 4s 106ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 6.0476e-04 - val_accuracy: 1.0000
# Epoch 49/50
# 35/35 [==============================] - 4s 109ms/step - loss: 9.6167e-04 - accuracy: 1.0000 - val_loss: 3.0403e-04 - val_accuracy: 1.0000
# Epoch 50/50
# 35/35 [==============================] - 4s 114ms/step - loss: 5.3652e-04 - accuracy: 1.0000 - val_loss: 1.2602e-04 - val_accuracy: 1.0000

# %%
# best val accuracy: 72.32
# use checkpoint to save the best val accuracy model
# adjust learning rate for slow convergence

# %% [markdown]
# ## Plot the results

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
model.save("your_model.h5")
